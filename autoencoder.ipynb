# %%
import pandas as pd
import numpy as np
# from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import re
import os

# %%
ratings_df = pd.read_csv('/home/manishn/recommend/data/ml-latest-small/ratings.csv')

# Load the movies data
movies_df = pd.read_csv('/home/manishn/recommend/data/ml-latest-small/movies.csv')

# Merge the DataFrames on 'movieId'
merged_df = pd.merge(ratings_df, movies_df, on='movieId')

# Optionally, reorder the columns if needed
merged_df = merged_df[['userId', 'movieId', 'title', 'genres', 'rating', 'timestamp']]

# %%
# Save the merged DataFrame to a new CSV file
merged_df.to_csv('merged_ratings.csv', index=False)
merged_df
data=pd.DataFrame()
data=merged_df
# data=pd.read_csv('/home/manishn/recommend/data/ml-latest-small/ratings.csv')
data.head()
# Out:
#    userId  movieId             title  \
# 0       1        1  Toy Story (1995)
# 1       5        1  Toy Story (1995)
# 2       7        1  Toy Story (1995)
# 3      15        1  Toy Story (1995)
# 4      17        1  Toy Story (1995)
#
#                                         genres  rating   timestamp
# 0  Adventure|Animation|Children|Comedy|Fantasy     4.0   964982703
# 1  Adventure|Animation|Children|Comedy|Fantasy     4.0   847434962
# 2  Adventure|Animation|Children|Comedy|Fantasy     4.5  1106635946
# 3  Adventure|Animation|Children|Comedy|Fantasy     2.5  1510577970
# 4  Adventure|Animation|Children|Comedy|Fantasy     4.5  1305696483

# %%
MatrixData=data.drop(['timestamp','genres','title'], axis=1)
MovieUserMatrix = MatrixData.pivot_table(index='movieId',columns='userId',values='rating')
MovieUserMatrix.head()
MovieUserMatrix_Y=MovieUserMatrix.fillna(5)
MovieUserMatrix_Y
MovieUserMatrix_R=MovieUserMatrix.copy()
MovieUserMatrix_R=MovieUserMatrix_R.where(~MovieUserMatrix_R.notna(), 1)
MovieUserMatrix_R=MovieUserMatrix_R.fillna(0)
MovieUserMatrix_R
Y=MovieUserMatrix_Y.values #converting to numpy array
R=MovieUserMatrix_R.values
Y.shape
# Out:
# (9724, 610)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

def split_data(Y, R, test_size=0.2):
    num_movies, num_users = Y.shape
    test_indices = np.random.choice(num_movies, size=int(num_movies * test_size), replace=False)
    
    # Initialize the test set
    Y_test = np.full_like(Y, fill_value=-1, dtype=np.float32)  # Use -1 for missing ratings
    R_test = np.zeros_like(R, dtype=np.float32)  # Binary indicator for test set
    
    # Fill the test set
    for idx in test_indices:
        Y_test[idx, :] = Y[idx, :]
        R_test[idx, :] = R[idx, :]
    
    # Create the training set by masking the test indices
    Y_train = Y.copy()
    R_train = R.copy()
    
    Y_train[test_indices, :] = -1  # Set test entries to -1 in the training set
    R_train[test_indices, :] = 0    # Set test entries to 0 in the training set
    
    return Y_train, R_train, Y_test, R_test

# %%
Y_train, R_train, Y_test, R_test = split_data(Y, R)

# Step 2: Convert the NumPy arrays to PyTorch tensors
Y_train_tensor = torch.FloatTensor(Y_train)
R_train_tensor = torch.FloatTensor(R_train)
Y_test_tensor = torch.FloatTensor(Y_test)
R_test_tensor = torch.FloatTensor(R_test)

# Step 3: Create a PyTorch Dataset and DataLoader for training
train_dataset = TensorDataset(Y_train_tensor, R_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)

# %%
class Autoencoder(nn.Module):
    def __init__(self, num_users, latent_dim,dropout=0.2):
        super(Autoencoder, self).__init__()
        self.dropout=nn.Dropout(dropout)
        self.encoder = nn.Linear(num_users, latent_dim)
        self.decoder = nn.Linear(latent_dim, num_users)
    
    def forward(self, x):
        encoded = self.dropout(torch.relu(self.encoder(x)))
        decoded = torch.sigmoid(self.dropout(self.decoder(encoded)))
        return decoded

# %%
num_movies, num_users = Y.shape
latent_dim = 200

model = Autoencoder(num_users, latent_dim)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
Y_train_tensor = Y_train_tensor.to(device)
R_train_tensor = R_train_tensor.to(device)

# Step 5: Training loop
num_epochs = 500

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    
    for batch_Y, batch_R in train_loader:
        batch_Y = batch_Y.to(device)
        batch_R = batch_R.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        output = model(batch_Y)
        
        # Only compute the loss where R == 1 (i.e., where the user provided a rating)
        loss = criterion(output * batch_R, batch_Y * batch_R)
        epoch_loss += loss.item()
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
    
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(train_loader):.4f}')

# Step 6: Testing the model after training
model.eval()
with torch.no_grad():
    predicted_ratings = model(Y_test_tensor.to(device))  # Get predicted ratings for the test set
    predicted_ratings = predicted_ratings.cpu().numpy()
# Out:
# Epoch 1/500, Loss: 0.1129
# Epoch 2/500, Loss: 0.1083
# Epoch 3/500, Loss: 0.1082
# Epoch 4/500, Loss: 0.1082
# Epoch 5/500, Loss: 0.1082
# Epoch 6/500, Loss: 0.1083
# Epoch 7/500, Loss: 0.1082
# Epoch 8/500, Loss: 0.1082
# Epoch 9/500, Loss: 0.1082
# Epoch 10/500, Loss: 0.1083
# Epoch 11/500, Loss: 0.1082
# Epoch 12/500, Loss: 0.1083
# Epoch 13/500, Loss: 0.1082
# Epoch 14/500, Loss: 0.1082
# Epoch 15/500, Loss: 0.1083
# Epoch 16/500, Loss: 0.1082
# Epoch 17/500, Loss: 0.1083
# Epoch 18/500, Loss: 0.1083
# Epoch 19/500, Loss: 0.1082
# Epoch 20/500, Loss: 0.1082
# Epoch 21/500, Loss: 0.1082
# Epoch 22/500, Loss: 0.1082
# Epoch 23/500, Loss: 0.1082
# Epoch 24/500, Loss: 0.1082
# Epoch 25/500, Loss: 0.1082
# Epoch 26/500, Loss: 0.1082
# Epoch 27/500, Loss: 0.1082
# Epoch 28/500, Loss: 0.1083
# Epoch 29/500, Loss: 0.1082
# Epoch 30/500, Loss: 0.1082
# Epoch 31/500, Loss: 0.1082
# Epoch 32/500, Loss: 0.1082
# Epoch 33/500, Loss: 0.1081
# Epoch 34/500, Loss: 0.1082
# Epoch 35/500, Loss: 0.1082
# Epoch 36/500, Loss: 0.1082
# Epoch 37/500, Loss: 0.1083
# Epoch 38/500, Loss: 0.1083
# Epoch 39/500, Loss: 0.1082
# Epoch 40/500, Loss: 0.1082
# Epoch 41/500, Loss: 0.1081
# Epoch 42/500, Loss: 0.1083
# Epoch 43/500, Loss: 0.1082
# Epoch 44/500, Loss: 0.1083
# Epoch 45/500, Loss: 0.1083
# Epoch 46/500, Loss: 0.1083
# Epoch 47/500, Loss: 0.1082
# Epoch 48/500, Loss: 0.1082
# Epoch 49/500, Loss: 0.1082
# Epoch 50/500, Loss: 0.1083
# Epoch 51/500, Loss: 0.1083
# Epoch 52/500, Loss: 0.1082
# Epoch 53/500, Loss: 0.1082
# Epoch 54/500, Loss: 0.1082
# Epoch 55/500, Loss: 0.1082
# Epoch 56/500, Loss: 0.1082
# Epoch 57/500, Loss: 0.1083
# Epoch 58/500, Loss: 0.1083
# Epoch 59/500, Loss: 0.1082
# Epoch 60/500, Loss: 0.1082
# Epoch 61/500, Loss: 0.1082
# Epoch 62/500, Loss: 0.1082
# Epoch 63/500, Loss: 0.1082
# Epoch 64/500, Loss: 0.1082
# Epoch 65/500, Loss: 0.1083
# Epoch 66/500, Loss: 0.1082
# Epoch 67/500, Loss: 0.1082
# Epoch 68/500, Loss: 0.1082
# Epoch 69/500, Loss: 0.1082
# Epoch 70/500, Loss: 0.1082
# Epoch 71/500, Loss: 0.1082
# Epoch 72/500, Loss: 0.1082
# Epoch 73/500, Loss: 0.1082
# Epoch 74/500, Loss: 0.1083
# Epoch 75/500, Loss: 0.1083
# Epoch 76/500, Loss: 0.1083
# Epoch 77/500, Loss: 0.1081
# Epoch 78/500, Loss: 0.1081
# Epoch 79/500, Loss: 0.1082
# Epoch 80/500, Loss: 0.1083
# Epoch 81/500, Loss: 0.1083
# Epoch 82/500, Loss: 0.1083
# Epoch 83/500, Loss: 0.1083
# Epoch 84/500, Loss: 0.1083
# Epoch 85/500, Loss: 0.1082
# Epoch 86/500, Loss: 0.1083
# Epoch 87/500, Loss: 0.1083
# Epoch 88/500, Loss: 0.1081
# Epoch 89/500, Loss: 0.1082
# Epoch 90/500, Loss: 0.1081
# Epoch 91/500, Loss: 0.1083
# Epoch 92/500, Loss: 0.1082
# Epoch 93/500, Loss: 0.1082
# Epoch 94/500, Loss: 0.1082
# Epoch 95/500, Loss: 0.1082
# Epoch 96/500, Loss: 0.1082
# Epoch 97/500, Loss: 0.1082
# Epoch 98/500, Loss: 0.1082
# Epoch 99/500, Loss: 0.1081
# Epoch 100/500, Loss: 0.1082
# Epoch 101/500, Loss: 0.1082
# Epoch 102/500, Loss: 0.1082
# Epoch 103/500, Loss: 0.1082
# Epoch 104/500, Loss: 0.1082
# Epoch 105/500, Loss: 0.1082
# Epoch 106/500, Loss: 0.1082
# Epoch 107/500, Loss: 0.1083
# Epoch 108/500, Loss: 0.1081
# Epoch 109/500, Loss: 0.1082
# Epoch 110/500, Loss: 0.1083
# Epoch 111/500, Loss: 0.1082
# Epoch 112/500, Loss: 0.1083
# Epoch 113/500, Loss: 0.1081
# Epoch 114/500, Loss: 0.1083
# Epoch 115/500, Loss: 0.1083
# Epoch 116/500, Loss: 0.1082
# Epoch 117/500, Loss: 0.1083
# Epoch 118/500, Loss: 0.1082
# Epoch 119/500, Loss: 0.1083
# Epoch 120/500, Loss: 0.1083
# Epoch 121/500, Loss: 0.1082
# Epoch 122/500, Loss: 0.1082
# Epoch 123/500, Loss: 0.1082
# Epoch 124/500, Loss: 0.1083
# Epoch 125/500, Loss: 0.1083
# Epoch 126/500, Loss: 0.1083
# Epoch 127/500, Loss: 0.1082
# Epoch 128/500, Loss: 0.1082
# Epoch 129/500, Loss: 0.1082
# Epoch 130/500, Loss: 0.1082
# Epoch 131/500, Loss: 0.1082
# Epoch 132/500, Loss: 0.1083
# Epoch 133/500, Loss: 0.1083
# Epoch 134/500, Loss: 0.1082
# Epoch 135/500, Loss: 0.1082
# Epoch 136/500, Loss: 0.1082
# Epoch 137/500, Loss: 0.1082
# Epoch 138/500, Loss: 0.1082
# Epoch 139/500, Loss: 0.1082
# Epoch 140/500, Loss: 0.1083
# Epoch 141/500, Loss: 0.1082
# Epoch 142/500, Loss: 0.1082
# Epoch 143/500, Loss: 0.1082
# Epoch 144/500, Loss: 0.1082
# Epoch 145/500, Loss: 0.1082
# Epoch 146/500, Loss: 0.1082
# Epoch 147/500, Loss: 0.1082
# Epoch 148/500, Loss: 0.1082
# Epoch 149/500, Loss: 0.1082
# Epoch 150/500, Loss: 0.1082
# Epoch 151/500, Loss: 0.1083
# Epoch 152/500, Loss: 0.1082
# Epoch 153/500, Loss: 0.1082
# Epoch 154/500, Loss: 0.1083
# Epoch 155/500, Loss: 0.1081
# Epoch 156/500, Loss: 0.1082
# Epoch 157/500, Loss: 0.1082
# Epoch 158/500, Loss: 0.1081
# Epoch 159/500, Loss: 0.1082
# Epoch 160/500, Loss: 0.1082
# Epoch 161/500, Loss: 0.1082
# Epoch 162/500, Loss: 0.1082
# Epoch 163/500, Loss: 0.1082
# Epoch 164/500, Loss: 0.1082
# Epoch 165/500, Loss: 0.1081
# Epoch 166/500, Loss: 0.1082
# Epoch 167/500, Loss: 0.1082
# Epoch 168/500, Loss: 0.1083
# Epoch 169/500, Loss: 0.1082
# Epoch 170/500, Loss: 0.1081
# Epoch 171/500, Loss: 0.1082
# Epoch 172/500, Loss: 0.1082
# Epoch 173/500, Loss: 0.1082
# Epoch 174/500, Loss: 0.1082
# Epoch 175/500, Loss: 0.1082
# Epoch 176/500, Loss: 0.1082
# Epoch 177/500, Loss: 0.1083
# Epoch 178/500, Loss: 0.1082
# Epoch 179/500, Loss: 0.1082
# Epoch 180/500, Loss: 0.1082
# Epoch 181/500, Loss: 0.1082
# Epoch 182/500, Loss: 0.1083
# Epoch 183/500, Loss: 0.1083
# Epoch 184/500, Loss: 0.1084
# Epoch 185/500, Loss: 0.1082
# Epoch 186/500, Loss: 0.1082
# Epoch 187/500, Loss: 0.1082
# Epoch 188/500, Loss: 0.1082
# Epoch 189/500, Loss: 0.1081
# Epoch 190/500, Loss: 0.1082
# Epoch 191/500, Loss: 0.1082
# Epoch 192/500, Loss: 0.1083
# Epoch 193/500, Loss: 0.1082
# Epoch 194/500, Loss: 0.1082
# Epoch 195/500, Loss: 0.1082
# Epoch 196/500, Loss: 0.1081
# Epoch 197/500, Loss: 0.1082
# Epoch 198/500, Loss: 0.1082
# Epoch 199/500, Loss: 0.1083
# Epoch 200/500, Loss: 0.1083
# Epoch 201/500, Loss: 0.1083
# Epoch 202/500, Loss: 0.1083
# Epoch 203/500, Loss: 0.1082
# Epoch 204/500, Loss: 0.1081
# Epoch 205/500, Loss: 0.1082
# Epoch 206/500, Loss: 0.1082
# Epoch 207/500, Loss: 0.1082
# Epoch 208/500, Loss: 0.1082
# Epoch 209/500, Loss: 0.1082
# Epoch 210/500, Loss: 0.1082
# Epoch 211/500, Loss: 0.1082
# Epoch 212/500, Loss: 0.1081
# Epoch 213/500, Loss: 0.1082
# Epoch 214/500, Loss: 0.1082
# Epoch 215/500, Loss: 0.1082
# Epoch 216/500, Loss: 0.1082
# Epoch 217/500, Loss: 0.1082
# Epoch 218/500, Loss: 0.1082
# Epoch 219/500, Loss: 0.1083
# Epoch 220/500, Loss: 0.1082
# Epoch 221/500, Loss: 0.1083
# Epoch 222/500, Loss: 0.1082
# Epoch 223/500, Loss: 0.1082
# Epoch 224/500, Loss: 0.1083
# Epoch 225/500, Loss: 0.1083
# Epoch 226/500, Loss: 0.1082
# Epoch 227/500, Loss: 0.1083
# Epoch 228/500, Loss: 0.1082
# Epoch 229/500, Loss: 0.1082
# Epoch 230/500, Loss: 0.1082
# Epoch 231/500, Loss: 0.1082
# Epoch 232/500, Loss: 0.1082
# Epoch 233/500, Loss: 0.1083
# Epoch 234/500, Loss: 0.1082
# Epoch 235/500, Loss: 0.1083
# Epoch 236/500, Loss: 0.1082
# Epoch 237/500, Loss: 0.1083
# Epoch 238/500, Loss: 0.1082
# Epoch 239/500, Loss: 0.1083
# Epoch 240/500, Loss: 0.1083
# Epoch 241/500, Loss: 0.1082
# Epoch 242/500, Loss: 0.1082
# Epoch 243/500, Loss: 0.1082
# Epoch 244/500, Loss: 0.1082
# Epoch 245/500, Loss: 0.1083
# Epoch 246/500, Loss: 0.1082
# Epoch 247/500, Loss: 0.1081
# Epoch 248/500, Loss: 0.1083
# Epoch 249/500, Loss: 0.1082
# Epoch 250/500, Loss: 0.1082
# Epoch 251/500, Loss: 0.1082
# Epoch 252/500, Loss: 0.1083
# Epoch 253/500, Loss: 0.1083
# Epoch 254/500, Loss: 0.1082
# Epoch 255/500, Loss: 0.1082
# Epoch 256/500, Loss: 0.1082
# Epoch 257/500, Loss: 0.1082
# Epoch 258/500, Loss: 0.1082
# Epoch 259/500, Loss: 0.1083
# Epoch 260/500, Loss: 0.1083
# Epoch 261/500, Loss: 0.1082
# Epoch 262/500, Loss: 0.1082
# Epoch 263/500, Loss: 0.1082
# Epoch 264/500, Loss: 0.1083
# Epoch 265/500, Loss: 0.1083
# Epoch 266/500, Loss: 0.1082
# Epoch 267/500, Loss: 0.1081
# Epoch 268/500, Loss: 0.1082
# Epoch 269/500, Loss: 0.1083
# Epoch 270/500, Loss: 0.1082
# Epoch 271/500, Loss: 0.1082
# Epoch 272/500, Loss: 0.1083
# Epoch 273/500, Loss: 0.1083
# Epoch 274/500, Loss: 0.1082
# Epoch 275/500, Loss: 0.1083
# Epoch 276/500, Loss: 0.1082
# Epoch 277/500, Loss: 0.1082
# Epoch 278/500, Loss: 0.1082
# Epoch 279/500, Loss: 0.1083
# Epoch 280/500, Loss: 0.1082
# Epoch 281/500, Loss: 0.1083
# Epoch 282/500, Loss: 0.1083
# Epoch 283/500, Loss: 0.1082
# Epoch 284/500, Loss: 0.1082
# Epoch 285/500, Loss: 0.1083
# Epoch 286/500, Loss: 0.1082
# Epoch 287/500, Loss: 0.1083
# Epoch 288/500, Loss: 0.1082
# Epoch 289/500, Loss: 0.1083
# Epoch 290/500, Loss: 0.1082
# Epoch 291/500, Loss: 0.1082
# Epoch 292/500, Loss: 0.1082
# Epoch 293/500, Loss: 0.1081
# Epoch 294/500, Loss: 0.1081
# Epoch 295/500, Loss: 0.1082
# Epoch 296/500, Loss: 0.1082
# Epoch 297/500, Loss: 0.1081
# Epoch 298/500, Loss: 0.1083
# Epoch 299/500, Loss: 0.1082
# Epoch 300/500, Loss: 0.1082
# Epoch 301/500, Loss: 0.1082
# Epoch 302/500, Loss: 0.1082
# Epoch 303/500, Loss: 0.1082
# Epoch 304/500, Loss: 0.1082
# Epoch 305/500, Loss: 0.1082
# Epoch 306/500, Loss: 0.1082
# Epoch 307/500, Loss: 0.1083
# Epoch 308/500, Loss: 0.1082
# Epoch 309/500, Loss: 0.1083
# Epoch 310/500, Loss: 0.1082
# Epoch 311/500, Loss: 0.1082
# Epoch 312/500, Loss: 0.1083
# Epoch 313/500, Loss: 0.1083
# Epoch 314/500, Loss: 0.1083
# Epoch 315/500, Loss: 0.1082
# Epoch 316/500, Loss: 0.1083
# Epoch 317/500, Loss: 0.1082
# Epoch 318/500, Loss: 0.1081
# Epoch 319/500, Loss: 0.1082
# Epoch 320/500, Loss: 0.1083
# Epoch 321/500, Loss: 0.1082
# Epoch 322/500, Loss: 0.1082
# Epoch 323/500, Loss: 0.1082
# Epoch 324/500, Loss: 0.1082
# Epoch 325/500, Loss: 0.1082
# Epoch 326/500, Loss: 0.1082
# Epoch 327/500, Loss: 0.1083
# Epoch 328/500, Loss: 0.1082
# Epoch 329/500, Loss: 0.1082
# Epoch 330/500, Loss: 0.1082
# Epoch 331/500, Loss: 0.1082
# Epoch 332/500, Loss: 0.1082
# Epoch 333/500, Loss: 0.1081
# Epoch 334/500, Loss: 0.1081
# Epoch 335/500, Loss: 0.1082
# Epoch 336/500, Loss: 0.1083
# Epoch 337/500, Loss: 0.1082
# Epoch 338/500, Loss: 0.1083
# Epoch 339/500, Loss: 0.1083
# Epoch 340/500, Loss: 0.1082
# Epoch 341/500, Loss: 0.1082
# Epoch 342/500, Loss: 0.1083
# Epoch 343/500, Loss: 0.1083
# Epoch 344/500, Loss: 0.1083
# Epoch 345/500, Loss: 0.1081
# Epoch 346/500, Loss: 0.1083
# Epoch 347/500, Loss: 0.1083
# Epoch 348/500, Loss: 0.1083
# Epoch 349/500, Loss: 0.1082
# Epoch 350/500, Loss: 0.1083
# Epoch 351/500, Loss: 0.1083
# Epoch 352/500, Loss: 0.1083
# Epoch 353/500, Loss: 0.1082
# Epoch 354/500, Loss: 0.1083
# Epoch 355/500, Loss: 0.1081
# Epoch 356/500, Loss: 0.1082
# Epoch 357/500, Loss: 0.1082
# Epoch 358/500, Loss: 0.1082
# Epoch 359/500, Loss: 0.1081
# Epoch 360/500, Loss: 0.1082
# Epoch 361/500, Loss: 0.1083
# Epoch 362/500, Loss: 0.1082
# Epoch 363/500, Loss: 0.1082
# Epoch 364/500, Loss: 0.1082
# Epoch 365/500, Loss: 0.1083
# Epoch 366/500, Loss: 0.1082
# Epoch 367/500, Loss: 0.1082
# Epoch 368/500, Loss: 0.1082
# Epoch 369/500, Loss: 0.1082
# Epoch 370/500, Loss: 0.1082
# Epoch 371/500, Loss: 0.1082
# Epoch 372/500, Loss: 0.1082
# Epoch 373/500, Loss: 0.1082
# Epoch 374/500, Loss: 0.1083
# Epoch 375/500, Loss: 0.1082
# Epoch 376/500, Loss: 0.1082
# Epoch 377/500, Loss: 0.1082
# Epoch 378/500, Loss: 0.1081
# Epoch 379/500, Loss: 0.1081
# Epoch 380/500, Loss: 0.1082
# Epoch 381/500, Loss: 0.1083
# Epoch 382/500, Loss: 0.1083
# Epoch 383/500, Loss: 0.1082
# Epoch 384/500, Loss: 0.1082
# Epoch 385/500, Loss: 0.1081
# Epoch 386/500, Loss: 0.1083
# Epoch 387/500, Loss: 0.1082
# Epoch 388/500, Loss: 0.1083
# Epoch 389/500, Loss: 0.1082
# Epoch 390/500, Loss: 0.1083
# Epoch 391/500, Loss: 0.1082
# Epoch 392/500, Loss: 0.1083
# Epoch 393/500, Loss: 0.1082
# Epoch 394/500, Loss: 0.1083
# Epoch 395/500, Loss: 0.1082
# Epoch 396/500, Loss: 0.1082
# Epoch 397/500, Loss: 0.1082
# Epoch 398/500, Loss: 0.1083
# Epoch 399/500, Loss: 0.1081
# Epoch 400/500, Loss: 0.1082
# Epoch 401/500, Loss: 0.1082
# Epoch 402/500, Loss: 0.1083
# Epoch 403/500, Loss: 0.1082
# Epoch 404/500, Loss: 0.1082
# Epoch 405/500, Loss: 0.1082
# Epoch 406/500, Loss: 0.1081
# Epoch 407/500, Loss: 0.1082
# Epoch 408/500, Loss: 0.1082
# Epoch 409/500, Loss: 0.1082
# Epoch 410/500, Loss: 0.1081
# Epoch 411/500, Loss: 0.1082
# Epoch 412/500, Loss: 0.1081
# Epoch 413/500, Loss: 0.1082
# Epoch 414/500, Loss: 0.1083
# Epoch 415/500, Loss: 0.1082
# Epoch 416/500, Loss: 0.1082
# Epoch 417/500, Loss: 0.1082
# Epoch 418/500, Loss: 0.1082
# Epoch 419/500, Loss: 0.1082
# Epoch 420/500, Loss: 0.1083
# Epoch 421/500, Loss: 0.1083
# Epoch 422/500, Loss: 0.1081
# Epoch 423/500, Loss: 0.1082
# Epoch 424/500, Loss: 0.1082
# Epoch 425/500, Loss: 0.1082
# Epoch 426/500, Loss: 0.1082
# Epoch 427/500, Loss: 0.1082
# Epoch 428/500, Loss: 0.1082
# Epoch 429/500, Loss: 0.1083
# Epoch 430/500, Loss: 0.1082
# Epoch 431/500, Loss: 0.1082
# Epoch 432/500, Loss: 0.1082
# Epoch 433/500, Loss: 0.1082
# Epoch 434/500, Loss: 0.1083
# Epoch 435/500, Loss: 0.1082
# Epoch 436/500, Loss: 0.1083
# Epoch 437/500, Loss: 0.1083
# Epoch 438/500, Loss: 0.1083
# Epoch 439/500, Loss: 0.1083
# Epoch 440/500, Loss: 0.1081
# Epoch 441/500, Loss: 0.1082
# Epoch 442/500, Loss: 0.1081
# Epoch 443/500, Loss: 0.1082
# Epoch 444/500, Loss: 0.1081
# Epoch 445/500, Loss: 0.1082
# Epoch 446/500, Loss: 0.1082
# Epoch 447/500, Loss: 0.1082
# Epoch 448/500, Loss: 0.1083
# Epoch 449/500, Loss: 0.1082
# Epoch 450/500, Loss: 0.1082
# Epoch 451/500, Loss: 0.1082
# Epoch 452/500, Loss: 0.1082
# Epoch 453/500, Loss: 0.1082
# Epoch 454/500, Loss: 0.1082
# Epoch 455/500, Loss: 0.1083
# Epoch 456/500, Loss: 0.1082
# Epoch 457/500, Loss: 0.1084
# Epoch 458/500, Loss: 0.1083
# Epoch 459/500, Loss: 0.1082
# Epoch 460/500, Loss: 0.1083
# Epoch 461/500, Loss: 0.1082
# Epoch 462/500, Loss: 0.1082
# Epoch 463/500, Loss: 0.1082
# Epoch 464/500, Loss: 0.1083
# Epoch 465/500, Loss: 0.1082
# Epoch 466/500, Loss: 0.1081
# Epoch 467/500, Loss: 0.1082
# Epoch 468/500, Loss: 0.1083
# Epoch 469/500, Loss: 0.1083
# Epoch 470/500, Loss: 0.1082
# Epoch 471/500, Loss: 0.1081
# Epoch 472/500, Loss: 0.1081
# Epoch 473/500, Loss: 0.1083
# Epoch 474/500, Loss: 0.1082
# Epoch 475/500, Loss: 0.1083
# Epoch 476/500, Loss: 0.1082
# Epoch 477/500, Loss: 0.1082
# Epoch 478/500, Loss: 0.1082
# Epoch 479/500, Loss: 0.1083
# Epoch 480/500, Loss: 0.1081
# Epoch 481/500, Loss: 0.1082
# Epoch 482/500, Loss: 0.1082
# Epoch 483/500, Loss: 0.1083
# Epoch 484/500, Loss: 0.1081
# Epoch 485/500, Loss: 0.1083
# Epoch 486/500, Loss: 0.1083
# Epoch 487/500, Loss: 0.1082
# Epoch 488/500, Loss: 0.1083
# Epoch 489/500, Loss: 0.1082
# Epoch 490/500, Loss: 0.1082
# Epoch 491/500, Loss: 0.1083
# Epoch 492/500, Loss: 0.1082
# Epoch 493/500, Loss: 0.1083
# Epoch 494/500, Loss: 0.1083
# Epoch 495/500, Loss: 0.1081
# Epoch 496/500, Loss: 0.1083
# Epoch 497/500, Loss: 0.1082
# Epoch 498/500, Loss: 0.1082
# Epoch 499/500, Loss: 0.1081
# Epoch 500/500, Loss: 0.1083

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# Assuming Y_train_tensor and R_train_tensor are already defined
num_movies, num_users = Y.shape
latent_dim = 200

model = Autoencoder(num_users, latent_dim)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
Y_train_tensor = Y_train_tensor.to(device)
R_train_tensor = R_train_tensor.to(device)

# Step 5: Training loop
num_epochs = 500

# Define RMSE computation function
def computeRMSE(Y, R, Y_pred):
    error = (Y_pred - Y) * R  # Only consider entries where R == 1
    squared_error = np.square(error)
    mse = np.sum(squared_error) / np.count_nonzero(R)
    return np.sqrt(mse)

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    
    for batch_Y, batch_R in train_loader:
        batch_Y = batch_Y.to(device)
        batch_R = batch_R.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        output = model(batch_Y)
        
        # Only compute the loss where R == 1 (i.e., where the user provided a rating)
        loss = criterion(output * batch_R, batch_Y * batch_R)
        epoch_loss += loss.item()
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
    
    # Calculate training RMSE after each epoch
    with torch.no_grad():
        predicted_ratings = model(Y_train_tensor)  # Get predicted ratings for the training set
        predicted_ratings = predicted_ratings.cpu().numpy()  # Convert to NumPy for RMSE calculation
        train_rmse = computeRMSE(Y_train_tensor.cpu().numpy(), R_train_tensor.cpu().numpy(), predicted_ratings)
    
    print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss / len(train_loader):.4f}, Train RMSE: {train_rmse:.4f}')

# Step 6: Testing the model after training
model.eval()
with torch.no_grad():
    predicted_ratings = model(Y_test_tensor.to(device))  # Get predicted ratings for the test set
    predicted_ratings = predicted_ratings.cpu().numpy()

# Step 8: Compute RMSE for the test set
rmse = computeRMSE(Y_test, R_test, predicted_ratings)
print(f"Test RMSE: {rmse:.4f}")
# Out:
# Epoch 1/500, Loss: 0.1129, Train RMSE: 2.8166
# Epoch 2/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 3/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 4/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 5/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 6/500, Loss: 0.1086, Train RMSE: 2.8151
# Epoch 7/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 8/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 9/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 10/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 11/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 12/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 13/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 14/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 15/500, Loss: 0.1086, Train RMSE: 2.8156
# Epoch 16/500, Loss: 0.1085, Train RMSE: 2.8170
# Epoch 17/500, Loss: 0.1085, Train RMSE: 2.8174
# Epoch 18/500, Loss: 0.1085, Train RMSE: 2.8158
# Epoch 19/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 20/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 21/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 22/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 23/500, Loss: 0.1086, Train RMSE: 2.8141
# Epoch 24/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 25/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 26/500, Loss: 0.1086, Train RMSE: 2.8165
# Epoch 27/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 28/500, Loss: 0.1085, Train RMSE: 2.8169
# Epoch 29/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 30/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 31/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 32/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 33/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 34/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 35/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 36/500, Loss: 0.1086, Train RMSE: 2.8141
# Epoch 37/500, Loss: 0.1086, Train RMSE: 2.8139
# Epoch 38/500, Loss: 0.1084, Train RMSE: 2.8148
# Epoch 39/500, Loss: 0.1086, Train RMSE: 2.8147
# Epoch 40/500, Loss: 0.1087, Train RMSE: 2.8152
# Epoch 41/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 42/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 43/500, Loss: 0.1086, Train RMSE: 2.8147
# Epoch 44/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 45/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 46/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 47/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 48/500, Loss: 0.1085, Train RMSE: 2.8161
# Epoch 49/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 50/500, Loss: 0.1086, Train RMSE: 2.8149
# Epoch 51/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 52/500, Loss: 0.1086, Train RMSE: 2.8141
# Epoch 53/500, Loss: 0.1087, Train RMSE: 2.8154
# Epoch 54/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 55/500, Loss: 0.1085, Train RMSE: 2.8162
# Epoch 56/500, Loss: 0.1086, Train RMSE: 2.8159
# Epoch 57/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 58/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 59/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 60/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 61/500, Loss: 0.1084, Train RMSE: 2.8159
# Epoch 62/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 63/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 64/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 65/500, Loss: 0.1084, Train RMSE: 2.8149
# Epoch 66/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 67/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 68/500, Loss: 0.1087, Train RMSE: 2.8150
# Epoch 69/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 70/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 71/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 72/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 73/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 74/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 75/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 76/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 77/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 78/500, Loss: 0.1085, Train RMSE: 2.8143
# Epoch 79/500, Loss: 0.1086, Train RMSE: 2.8136
# Epoch 80/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 81/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 82/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 83/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 84/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 85/500, Loss: 0.1086, Train RMSE: 2.8138
# Epoch 86/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 87/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 88/500, Loss: 0.1086, Train RMSE: 2.8164
# Epoch 89/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 90/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 91/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 92/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 93/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 94/500, Loss: 0.1085, Train RMSE: 2.8158
# Epoch 95/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 96/500, Loss: 0.1085, Train RMSE: 2.8162
# Epoch 97/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 98/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 99/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 100/500, Loss: 0.1084, Train RMSE: 2.8150
# Epoch 101/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 102/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 103/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 104/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 105/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 106/500, Loss: 0.1086, Train RMSE: 2.8156
# Epoch 107/500, Loss: 0.1086, Train RMSE: 2.8151
# Epoch 108/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 109/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 110/500, Loss: 0.1085, Train RMSE: 2.8166
# Epoch 111/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 112/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 113/500, Loss: 0.1085, Train RMSE: 2.8143
# Epoch 114/500, Loss: 0.1086, Train RMSE: 2.8146
# Epoch 115/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 116/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 117/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 118/500, Loss: 0.1084, Train RMSE: 2.8150
# Epoch 119/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 120/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 121/500, Loss: 0.1085, Train RMSE: 2.8165
# Epoch 122/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 123/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 124/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 125/500, Loss: 0.1087, Train RMSE: 2.8156
# Epoch 126/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 127/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 128/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 129/500, Loss: 0.1085, Train RMSE: 2.8137
# Epoch 130/500, Loss: 0.1084, Train RMSE: 2.8150
# Epoch 131/500, Loss: 0.1086, Train RMSE: 2.8146
# Epoch 132/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 133/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 134/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 135/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 136/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 137/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 138/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 139/500, Loss: 0.1086, Train RMSE: 2.8134
# Epoch 140/500, Loss: 0.1084, Train RMSE: 2.8145
# Epoch 141/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 142/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 143/500, Loss: 0.1086, Train RMSE: 2.8139
# Epoch 144/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 145/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 146/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 147/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 148/500, Loss: 0.1086, Train RMSE: 2.8158
# Epoch 149/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 150/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 151/500, Loss: 0.1084, Train RMSE: 2.8148
# Epoch 152/500, Loss: 0.1086, Train RMSE: 2.8147
# Epoch 153/500, Loss: 0.1086, Train RMSE: 2.8154
# Epoch 154/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 155/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 156/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 157/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 158/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 159/500, Loss: 0.1086, Train RMSE: 2.8158
# Epoch 160/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 161/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 162/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 163/500, Loss: 0.1086, Train RMSE: 2.8146
# Epoch 164/500, Loss: 0.1085, Train RMSE: 2.8143
# Epoch 165/500, Loss: 0.1085, Train RMSE: 2.8125
# Epoch 166/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 167/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 168/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 169/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 170/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 171/500, Loss: 0.1086, Train RMSE: 2.8160
# Epoch 172/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 173/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 174/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 175/500, Loss: 0.1084, Train RMSE: 2.8145
# Epoch 176/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 177/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 178/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 179/500, Loss: 0.1085, Train RMSE: 2.8138
# Epoch 180/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 181/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 182/500, Loss: 0.1085, Train RMSE: 2.8158
# Epoch 183/500, Loss: 0.1086, Train RMSE: 2.8154
# Epoch 184/500, Loss: 0.1085, Train RMSE: 2.8138
# Epoch 185/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 186/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 187/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 188/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 189/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 190/500, Loss: 0.1087, Train RMSE: 2.8144
# Epoch 191/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 192/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 193/500, Loss: 0.1086, Train RMSE: 2.8166
# Epoch 194/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 195/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 196/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 197/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 198/500, Loss: 0.1084, Train RMSE: 2.8137
# Epoch 199/500, Loss: 0.1084, Train RMSE: 2.8148
# Epoch 200/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 201/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 202/500, Loss: 0.1085, Train RMSE: 2.8165
# Epoch 203/500, Loss: 0.1085, Train RMSE: 2.8131
# Epoch 204/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 205/500, Loss: 0.1086, Train RMSE: 2.8167
# Epoch 206/500, Loss: 0.1085, Train RMSE: 2.8159
# Epoch 207/500, Loss: 0.1084, Train RMSE: 2.8152
# Epoch 208/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 209/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 210/500, Loss: 0.1086, Train RMSE: 2.8141
# Epoch 211/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 212/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 213/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 214/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 215/500, Loss: 0.1086, Train RMSE: 2.8162
# Epoch 216/500, Loss: 0.1084, Train RMSE: 2.8144
# Epoch 217/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 218/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 219/500, Loss: 0.1086, Train RMSE: 2.8160
# Epoch 220/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 221/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 222/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 223/500, Loss: 0.1085, Train RMSE: 2.8162
# Epoch 224/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 225/500, Loss: 0.1084, Train RMSE: 2.8162
# Epoch 226/500, Loss: 0.1085, Train RMSE: 2.8135
# Epoch 227/500, Loss: 0.1086, Train RMSE: 2.8159
# Epoch 228/500, Loss: 0.1084, Train RMSE: 2.8145
# Epoch 229/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 230/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 231/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 232/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 233/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 234/500, Loss: 0.1086, Train RMSE: 2.8149
# Epoch 235/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 236/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 237/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 238/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 239/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 240/500, Loss: 0.1084, Train RMSE: 2.8147
# Epoch 241/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 242/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 243/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 244/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 245/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 246/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 247/500, Loss: 0.1087, Train RMSE: 2.8147
# Epoch 248/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 249/500, Loss: 0.1085, Train RMSE: 2.8128
# Epoch 250/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 251/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 252/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 253/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 254/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 255/500, Loss: 0.1087, Train RMSE: 2.8158
# Epoch 256/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 257/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 258/500, Loss: 0.1084, Train RMSE: 2.8158
# Epoch 259/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 260/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 261/500, Loss: 0.1086, Train RMSE: 2.8149
# Epoch 262/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 263/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 264/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 265/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 266/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 267/500, Loss: 0.1086, Train RMSE: 2.8136
# Epoch 268/500, Loss: 0.1086, Train RMSE: 2.8168
# Epoch 269/500, Loss: 0.1084, Train RMSE: 2.8143
# Epoch 270/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 271/500, Loss: 0.1085, Train RMSE: 2.8161
# Epoch 272/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 273/500, Loss: 0.1086, Train RMSE: 2.8136
# Epoch 274/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 275/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 276/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 277/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 278/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 279/500, Loss: 0.1085, Train RMSE: 2.8136
# Epoch 280/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 281/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 282/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 283/500, Loss: 0.1087, Train RMSE: 2.8151
# Epoch 284/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 285/500, Loss: 0.1085, Train RMSE: 2.8135
# Epoch 286/500, Loss: 0.1086, Train RMSE: 2.8132
# Epoch 287/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 288/500, Loss: 0.1084, Train RMSE: 2.8150
# Epoch 289/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 290/500, Loss: 0.1085, Train RMSE: 2.8165
# Epoch 291/500, Loss: 0.1086, Train RMSE: 2.8141
# Epoch 292/500, Loss: 0.1085, Train RMSE: 2.8134
# Epoch 293/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 294/500, Loss: 0.1085, Train RMSE: 2.8143
# Epoch 295/500, Loss: 0.1086, Train RMSE: 2.8140
# Epoch 296/500, Loss: 0.1086, Train RMSE: 2.8156
# Epoch 297/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 298/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 299/500, Loss: 0.1085, Train RMSE: 2.8160
# Epoch 300/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 301/500, Loss: 0.1086, Train RMSE: 2.8161
# Epoch 302/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 303/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 304/500, Loss: 0.1086, Train RMSE: 2.8163
# Epoch 305/500, Loss: 0.1084, Train RMSE: 2.8157
# Epoch 306/500, Loss: 0.1084, Train RMSE: 2.8153
# Epoch 307/500, Loss: 0.1085, Train RMSE: 2.8135
# Epoch 308/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 309/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 310/500, Loss: 0.1086, Train RMSE: 2.8151
# Epoch 311/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 312/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 313/500, Loss: 0.1087, Train RMSE: 2.8152
# Epoch 314/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 315/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 316/500, Loss: 0.1084, Train RMSE: 2.8164
# Epoch 317/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 318/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 319/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 320/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 321/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 322/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 323/500, Loss: 0.1085, Train RMSE: 2.8158
# Epoch 324/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 325/500, Loss: 0.1086, Train RMSE: 2.8163
# Epoch 326/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 327/500, Loss: 0.1086, Train RMSE: 2.8151
# Epoch 328/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 329/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 330/500, Loss: 0.1084, Train RMSE: 2.8144
# Epoch 331/500, Loss: 0.1086, Train RMSE: 2.8162
# Epoch 332/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 333/500, Loss: 0.1086, Train RMSE: 2.8162
# Epoch 334/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 335/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 336/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 337/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 338/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 339/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 340/500, Loss: 0.1086, Train RMSE: 2.8131
# Epoch 341/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 342/500, Loss: 0.1086, Train RMSE: 2.8146
# Epoch 343/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 344/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 345/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 346/500, Loss: 0.1086, Train RMSE: 2.8139
# Epoch 347/500, Loss: 0.1086, Train RMSE: 2.8158
# Epoch 348/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 349/500, Loss: 0.1084, Train RMSE: 2.8138
# Epoch 350/500, Loss: 0.1087, Train RMSE: 2.8150
# Epoch 351/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 352/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 353/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 354/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 355/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 356/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 357/500, Loss: 0.1084, Train RMSE: 2.8143
# Epoch 358/500, Loss: 0.1084, Train RMSE: 2.8143
# Epoch 359/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 360/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 361/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 362/500, Loss: 0.1087, Train RMSE: 2.8148
# Epoch 363/500, Loss: 0.1086, Train RMSE: 2.8169
# Epoch 364/500, Loss: 0.1084, Train RMSE: 2.8158
# Epoch 365/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 366/500, Loss: 0.1085, Train RMSE: 2.8136
# Epoch 367/500, Loss: 0.1086, Train RMSE: 2.8155
# Epoch 368/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 369/500, Loss: 0.1085, Train RMSE: 2.8158
# Epoch 370/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 371/500, Loss: 0.1086, Train RMSE: 2.8140
# Epoch 372/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 373/500, Loss: 0.1086, Train RMSE: 2.8156
# Epoch 374/500, Loss: 0.1084, Train RMSE: 2.8148
# Epoch 375/500, Loss: 0.1086, Train RMSE: 2.8145
# Epoch 376/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 377/500, Loss: 0.1086, Train RMSE: 2.8147
# Epoch 378/500, Loss: 0.1086, Train RMSE: 2.8156
# Epoch 379/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 380/500, Loss: 0.1086, Train RMSE: 2.8140
# Epoch 381/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 382/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 383/500, Loss: 0.1085, Train RMSE: 2.8137
# Epoch 384/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 385/500, Loss: 0.1085, Train RMSE: 2.8143
# Epoch 386/500, Loss: 0.1086, Train RMSE: 2.8160
# Epoch 387/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 388/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 389/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 390/500, Loss: 0.1086, Train RMSE: 2.8161
# Epoch 391/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 392/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 393/500, Loss: 0.1086, Train RMSE: 2.8134
# Epoch 394/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 395/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 396/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 397/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 398/500, Loss: 0.1085, Train RMSE: 2.8166
# Epoch 399/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 400/500, Loss: 0.1085, Train RMSE: 2.8155
# Epoch 401/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 402/500, Loss: 0.1086, Train RMSE: 2.8154
# Epoch 403/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 404/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 405/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 406/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 407/500, Loss: 0.1085, Train RMSE: 2.8143
# Epoch 408/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 409/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 410/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 411/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 412/500, Loss: 0.1084, Train RMSE: 2.8149
# Epoch 413/500, Loss: 0.1086, Train RMSE: 2.8154
# Epoch 414/500, Loss: 0.1084, Train RMSE: 2.8157
# Epoch 415/500, Loss: 0.1087, Train RMSE: 2.8155
# Epoch 416/500, Loss: 0.1085, Train RMSE: 2.8140
# Epoch 417/500, Loss: 0.1086, Train RMSE: 2.8147
# Epoch 418/500, Loss: 0.1085, Train RMSE: 2.8146
# Epoch 419/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 420/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 421/500, Loss: 0.1086, Train RMSE: 2.8154
# Epoch 422/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 423/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 424/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 425/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 426/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 427/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 428/500, Loss: 0.1086, Train RMSE: 2.8151
# Epoch 429/500, Loss: 0.1084, Train RMSE: 2.8136
# Epoch 430/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 431/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 432/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 433/500, Loss: 0.1086, Train RMSE: 2.8165
# Epoch 434/500, Loss: 0.1086, Train RMSE: 2.8149
# Epoch 435/500, Loss: 0.1084, Train RMSE: 2.8143
# Epoch 436/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 437/500, Loss: 0.1085, Train RMSE: 2.8156
# Epoch 438/500, Loss: 0.1086, Train RMSE: 2.8147
# Epoch 439/500, Loss: 0.1086, Train RMSE: 2.8154
# Epoch 440/500, Loss: 0.1086, Train RMSE: 2.8157
# Epoch 441/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 442/500, Loss: 0.1087, Train RMSE: 2.8165
# Epoch 443/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 444/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 445/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 446/500, Loss: 0.1085, Train RMSE: 2.8161
# Epoch 447/500, Loss: 0.1084, Train RMSE: 2.8160
# Epoch 448/500, Loss: 0.1086, Train RMSE: 2.8138
# Epoch 449/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 450/500, Loss: 0.1086, Train RMSE: 2.8140
# Epoch 451/500, Loss: 0.1086, Train RMSE: 2.8143
# Epoch 452/500, Loss: 0.1086, Train RMSE: 2.8153
# Epoch 453/500, Loss: 0.1087, Train RMSE: 2.8143
# Epoch 454/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 455/500, Loss: 0.1086, Train RMSE: 2.8152
# Epoch 456/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 457/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 458/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 459/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 460/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 461/500, Loss: 0.1086, Train RMSE: 2.8167
# Epoch 462/500, Loss: 0.1085, Train RMSE: 2.8144
# Epoch 463/500, Loss: 0.1085, Train RMSE: 2.8137
# Epoch 464/500, Loss: 0.1085, Train RMSE: 2.8157
# Epoch 465/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 466/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 467/500, Loss: 0.1086, Train RMSE: 2.8160
# Epoch 468/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 469/500, Loss: 0.1085, Train RMSE: 2.8139
# Epoch 470/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 471/500, Loss: 0.1085, Train RMSE: 2.8164
# Epoch 472/500, Loss: 0.1086, Train RMSE: 2.8146
# Epoch 473/500, Loss: 0.1086, Train RMSE: 2.8149
# Epoch 474/500, Loss: 0.1086, Train RMSE: 2.8135
# Epoch 475/500, Loss: 0.1085, Train RMSE: 2.8141
# Epoch 476/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 477/500, Loss: 0.1086, Train RMSE: 2.8144
# Epoch 478/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 479/500, Loss: 0.1086, Train RMSE: 2.8146
# Epoch 480/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 481/500, Loss: 0.1085, Train RMSE: 2.8152
# Epoch 482/500, Loss: 0.1086, Train RMSE: 2.8150
# Epoch 483/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 484/500, Loss: 0.1085, Train RMSE: 2.8150
# Epoch 485/500, Loss: 0.1085, Train RMSE: 2.8148
# Epoch 486/500, Loss: 0.1086, Train RMSE: 2.8148
# Epoch 487/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 488/500, Loss: 0.1086, Train RMSE: 2.8137
# Epoch 489/500, Loss: 0.1086, Train RMSE: 2.8141
# Epoch 490/500, Loss: 0.1085, Train RMSE: 2.8145
# Epoch 491/500, Loss: 0.1085, Train RMSE: 2.8154
# Epoch 492/500, Loss: 0.1085, Train RMSE: 2.8161
# Epoch 493/500, Loss: 0.1085, Train RMSE: 2.8153
# Epoch 494/500, Loss: 0.1085, Train RMSE: 2.8151
# Epoch 495/500, Loss: 0.1084, Train RMSE: 2.8143
# Epoch 496/500, Loss: 0.1085, Train RMSE: 2.8149
# Epoch 497/500, Loss: 0.1085, Train RMSE: 2.8142
# Epoch 498/500, Loss: 0.1085, Train RMSE: 2.8147
# Epoch 499/500, Loss: 0.1086, Train RMSE: 2.8142
# Epoch 500/500, Loss: 0.1085, Train RMSE: 2.8146
# Test RMSE: 2.6885

# %%
# Convert predicted ratings back to NumPy for RMSE calculation
# predicted_ratings = predicted_ratings.cpu().numpy()

# Step 7: Define RMSE computation function
def computeTestError(Y_test, R_test, Y_pred):
    error = (Y_pred - Y_test) * R_test  # Only consider entries where R_test == 1
    squared_error = np.square(error)
    mse = np.sum(squared_error) / np.count_nonzero(R_test)
    return np.sqrt(mse)

# Step 8: Compute RMSE
rmse = computeTestError(Y_test, R_test, predicted_ratings)
print(f"Test RMSE: {rmse}")
# Out:
# Test RMSE: 2.6885017663140407

# %% [markdown]
# **improved model**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

def split_data(Y, R, test_size=0.2):
    num_movies, num_users = Y.shape
    test_indices = np.random.choice(num_movies, size=int(num_movies * test_size), replace=False)
    
    # Initialize the test set
    Y_test = np.full_like(Y, fill_value=-1, dtype=np.float32)  # Use -1 for missing ratings
    R_test = np.zeros_like(R, dtype=np.float32)  # Binary indicator for test set
    
    # Fill the test set
    for idx in test_indices:
        Y_test[idx, :] = Y[idx, :]
        R_test[idx, :] = R[idx, :]
    
    # Create the training set by masking the test indices
    Y_train = Y.copy()
    R_train = R.copy()
    
    Y_train[test_indices, :] = -1  # Set test entries to -1 in the training set
    R_train[test_indices, :] = 0    # Set test entries to 0 in the training set
    
    return Y_train, R_train, Y_test, R_test

Y_train, R_train, Y_test, R_test = split_data(Y, R)

# Step 2: Convert the NumPy arrays to PyTorch tensors
Y_train_tensor = torch.FloatTensor(Y_train)
R_train_tensor = torch.FloatTensor(R_train)
Y_test_tensor = torch.FloatTensor(Y_test)
R_test_tensor = torch.FloatTensor(R_test)

# Step 3: Create a PyTorch Dataset and DataLoader for training
train_dataset = TensorDataset(Y_train_tensor, R_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Define the Improved Autoencoder model
class ImprovedAutoencoder(nn.Module):
    def __init__(self, num_users, latent_dim, dropout=0.2):
        super(ImprovedAutoencoder, self).__init__()
        self.dropout = nn.Dropout(dropout)
        
        # Encoder with multiple hidden layers
        self.encoder = nn.Sequential(
            nn.Linear(num_users, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, latent_dim)
        )
        
        # Decoder with residual connections
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, num_users),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.dropout(self.encoder(x))
        decoded = self.dropout(self.decoder(encoded))
        return decoded + x  # Residual connection

# %%
# Initialize the model, loss function, and optimizer
num_movies, num_users = Y.shape  # (9724, 610)
latent_dim = 200  # Latent feature size

model = ImprovedAutoencoder(num_users, latent_dim)
criterion = nn.MSELoss()  # Mean Squared Error Loss
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

# Learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5)

# Move model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

Y_train_tensor = Y_train_tensor.to(device)
R_train_tensor = R_train_tensor.to(device)

Y_tensor = Y_train_tensor.to(device)
R_tensor = R_train_tensor.to(device)

# Training loop with early stopping
num_epochs = 100
best_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    
    for batch_Y, batch_R in train_loader:
        batch_Y = batch_Y.to(device)
        batch_R = batch_R.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        output = model(batch_Y)
        
        # Only compute the loss where R == 1 (i.e., where the user provided a rating)
        loss = criterion(output * batch_R, batch_Y * batch_R)
        epoch_loss += loss.item()
        
        # Backward pass and optimizationa
        loss.backward()
        optimizer.step()
    
    # Update the learning rate scheduler
    scheduler.step(epoch_loss)
    
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(train_loader):.4f}')

    # Early stopping
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        patience_counter = 0
        # Save model
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping!")
            break

# Load the best model for testing
model.load_state_dict(torch.load('best_model.pth'))

# Testing the model after training
model.eval()
with torch.no_grad():
    reconstructed = model(Y_tensor)
    test_loss = criterion(reconstructed * R_tensor, Y_tensor * R_tensor)
    print(f'Test Loss: {test_loss.item():.4f}')
# Out:
# Epoch 1/100, Loss: 0.0006
# Epoch 2/100, Loss: 0.0000
# Epoch 3/100, Loss: 0.0001
# Epoch 4/100, Loss: 0.0001
# Epoch 5/100, Loss: 0.0001
# Epoch 6/100, Loss: 0.0001
# Epoch 7/100, Loss: 0.0001
# Epoch 8/100, Loss: 0.0001
# Epoch 9/100, Loss: 0.0001
# Epoch 10/100, Loss: 0.0001
# Epoch 11/100, Loss: 0.0001
# Epoch 12/100, Loss: 0.0001
# Epoch 13/100, Loss: 0.0001
# Epoch 14/100, Loss: 0.0001
# Epoch 15/100, Loss: 0.0001
# Epoch 16/100, Loss: 0.0001
# Epoch 17/100, Loss: 0.0001
# Epoch 18/100, Loss: 0.0001
# Epoch 19/100, Loss: 0.0001
# Epoch 20/100, Loss: 0.0001
# Epoch 21/100, Loss: 0.0001
# Epoch 22/100, Loss: 0.0001
# Early stopping!
# Test Loss: 0.0008

# %%
# Convert predicted ratings back to NumPy for RMSE calculation
reconstructed = reconstructed.cpu().numpy()

# Step 7: Define RMSE computation function
def computeTestError(Y_test, R_test, Y_pred):
    error = (Y_pred - Y_test) * R_test  # Only consider entries where R_test == 1
    squared_error = np.square(error)
    mse = np.sum(squared_error) / np.count_nonzero(R_test)
    return np.sqrt(mse)

# Step 8: Compute RMSE
rmse = computeTestError(Y_test, R_test, reconstructed)
print(f"Test RMSE: {rmse}")
# Out:
# Test RMSE: 4.151440080718873
